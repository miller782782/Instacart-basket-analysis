# %% [markdown]
# # Task 4.8 - Grouping and Aggregating Data

# %% [markdown]
# ### 1. Importing libraries and Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Define path

path = r'/Users/andymiller/Desktop/CareerFoundry Data Analytics/4. Python/Aug 2025 Instacart Basket Analysis'

# %%
# Import ords_prods_merge.pkl

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined_4.7.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     0.0         196
# 1                   2                  8                     0.0       14084
# 2                   2                  8                     0.0       12427
# 3                   2                  8                     0.0       26088
# 4                   2                  8                     0.0       26405
#
#    add_to_cart_order  ...  _merge Unnamed: 0_y  \
# 0                  1  ...    both          195
# ...

# %%
#  #  There appears to be several redundant columns here that aren't in the examples in the exercise
#  Removing 'Unnamed: 0.1', 'Unnamed: 0_x', '_merge', 'Unnamed: 0_y'.

ords_prods_merge_2 = ords_prods_merge.drop(columns = (['Unnamed: 0.1', 'Unnamed: 0_x','_merge','Unnamed: 0_y']))

# %%
# Check that columns are gone

ords_prods_merge_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# ### 2. Find aggregated mean of 'order_number' grouped by 'department_id'

# %%
#  Aggregate mean order_number grouped by department_id

ords_prods_merge_2.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### 3. Comparing result to those of the subset taken previously

# %% [markdown]
# ##### The results after analysing the entire dataframe are not that different to those when analysing only the first 1'000'000 rows.  The 1'000'000 rows was a fairly representative sample of the full data set.

# %% [markdown]
# ### 4. Creating loyalty flags for existing customers

# %%
# Group by 'user_id' and add a column containing the max number of orders.

ords_prods_merge_2['max_order'] = ords_prods_merge_2.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_65466/1810770497.py:3: FutureWarning: The provided callable <function max at 0x106965080> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge_2['max_order'] = ords_prods_merge_2.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge_2.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# ...

# %%
# Add the loyalty_flag column and classify each customer as Loyal, Regular or New

ords_prods_merge_2.loc[ords_prods_merge_2['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge_2.loc[(ords_prods_merge_2['max_order'] <= 40) & (ords_prods_merge_2['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge_2.loc[ords_prods_merge_2['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge_2.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# ...

# %%
ords_prods_merge_2['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# The loyalty flags have been successfully added

# %% [markdown]
# ### 5. Check basic statistics for each loyalty category

# %%
# Look at the mean, median, min and max prices for items purchased by each loyalty group of customers

ords_prods_merge_2.groupby('loyalty_flag').agg({'prices': ['mean', 'median', 'min', 'max']})
# Out:
#                      prices
#                        mean median  min      max
# loyalty_flag
# Loyal customer    10.386336    7.4  1.0  99999.0
# New customer      13.294670    7.4  1.0  99999.0
# Regular customer  12.495717    7.4  1.0  99999.0

# %% [markdown]
# ##### It looks as if new customers are attracted to the more expensive items averaging 13.29 per item whereas regular customers spend on average 0.79 less per item averaging 12.50.  Meanwhile the loyal customers average considerably less at just 10.39 per item.  The max price seems unrealistic and will require further investigation.

# %% [markdown]
# ### 6. Create a spending flag for each user based on the average price across all their orders

# %%
#  First let's find the average item price for each user

ords_prods_merge_2.groupby('user_id').agg({'prices': ['mean', 'median', 'min', 'max']})
# Out:
#            prices
#              mean median  min   max
# user_id
# 1        6.367797   4.70  1.0  14.0
# 2        7.515897   6.60  1.3  14.8
# 3        8.197727   8.20  1.3  14.4
# 4        8.205556   9.00  1.4  14.6
# 5        9.189189   8.60  3.2  14.8
# ...           ...    ...  ...   ...
# 206205   8.909375   9.05  1.4  23.8
# 206206   7.646667   6.70  1.1  14.8
# 206207   7.313453   6.80  1.2  24.7
# 206208   8.366617   8.00  1.1  21.6
# 206209   7.058915   5.90  1.1  18.8
#
# [206209 rows x 4 columns]

# %%
#  Now that we can see some of these figures, we can add a column for the 'mean_item_price'

ords_prods_merge_2['mean_item_price'] = ords_prods_merge_2.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_65466/2976801014.py:3: FutureWarning: The provided callable <function mean at 0x106965a80> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge_2['mean_item_price'] = ords_prods_merge_2.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# Add the spending_flag column and classify each customer as High spender or Low spender

ords_prods_merge_2.loc[ords_prods_merge_2['mean_item_price'] < 10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merge_2.loc[ords_prods_merge_2['mean_item_price'] >= 10, 'spender_flag'] = 'High spender'

# %%
ords_prods_merge_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merge_2['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Creating a flag to distinguish frequent vs non-frequent customers

# %%
# Create a column median_days_since_prior_order

ords_prods_merge_2['median_days_since_prior_order'] = ords_prods_merge_2.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_65466/24842695.py:3: FutureWarning: The provided callable <function median at 0x106ab4fe0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge_2['median_days_since_prior_order'] = ords_prods_merge_2.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  ...  prices  merge_status  \
# ...

# %%
# Now add a frequent customer flag classiying each customer as "Non-frequent customer", 
# "Regular customer" or "Frequent customer".

ords_prods_merge_2.loc[ords_prods_merge_2['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge_2.loc[(ords_prods_merge_2['median_days_since_prior_order'] > 10) & (ords_prods_merge_2['median_days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge_2.loc[ords_prods_merge_2['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Checking Releavent Columns
ords_prods_merge_2[['user_id', 'mean_item_price', 'spender_flag', 'median_days_since_prior_order', 'order_frequency_flag']].head(15)
# Out:
#     user_id  mean_item_price spender_flag  median_days_since_prior_order  \
# 0         1         6.367797  Low spender                           20.0
# 1         1         6.367797  Low spender                           20.0
# 2         1         6.367797  Low spender                           20.0
# 3         1         6.367797  Low spender                           20.0
# 4         1         6.367797  Low spender                           20.0
# 5         1         6.367797  Low spender                           20.0
# 6         1         6.367797  Low spender                           20.0
# 7         1         6.367797  Low spender                           20.0
# 8         1         6.367797  Low spender                           20.0
# 9         1         6.367797  Low spender                           20.0
# 10        1         6.367797  Low spender                           20.0
# 11        1         6.367797  Low spender                           20.0
# ...

# %%
ords_prods_merge_2.shape
# Out:
# (32404859, 23)

# %%
# Check frequencies of flags

ords_prods_merge_2['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        22796659
# Regular customer          6921472
# Non-frequent customer     2686728
# Name: count, dtype: int64

# %% [markdown]
# ### 9. Export dataframe and pickle file

# %%
ords_prods_merge_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined_4.8.pkl'))
