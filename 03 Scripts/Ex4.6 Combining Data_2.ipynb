# %% [markdown]
# # Task 4.6 (Part 2)

# %%
# Import libraries and data

import pandas as pd
import numpy as np
import os

# %%
# Define path

path = r'/Users/andymiller/Desktop/CareerFoundry Data Analytics/4. Python/Aug 2025 Instacart Basket Analysis'

# %%
# 3. Import orders_products_combined.pkl

df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#  4. Check the shape of df_ords_prods

df_ords_prods.shape
# Out:
# (32434489, 12)

# %%
df_ords_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     0.0         196
# 1                   2                  8                     0.0       14084
# 2                   2                  8                     0.0       12427
# 3                   2                  8                     0.0       26088
# 4                   2                  8                     0.0       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Import df_prods from products_checked.csv

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# 5. Merge df_ords_prods with df_prods using the 'product_id' column

df_merged = df_ords_prods.merge(df_prods, on = 'product_id', indicator = 'merge_status')

# %%
# Check the shape and contents of df_merged

df_merged.shape
# Out:
# (32404859, 18)

# %%
# 6. Confirm results of merge using merge_status

df_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     0.0         196
# 1                   2                  8                     0.0       14084
# 2                   2                  8                     0.0       12427
# 3                   2                  8                     0.0       26088
# 4                   2                  8                     0.0       26405
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y  \
# 0                  1          0   both           195
# ...

# %%
df_merged.shape
# Out:
# (32404859, 18)

# %%
# 7. Export df_merged as a pickle file since the size is large.

df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
